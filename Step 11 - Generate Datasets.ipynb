# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
from utils import generate_file
from utils import generate_ampl

# %%
generate_file('data/test1.txt',
                 10, (700, 900), 
                 10, (500, 700),
                 10, (300, 500), 
                 21, (100, 300),
                 (1000, 1500), (1000, 1500),
                 (1, 10), (1, 10), (1, 10), random_state=42
             )

# %%
generate_ampl('data/test1.txt', 'data/test1_ampl.mod')

# %%
generate_file('data/test2.txt',
                 20, (700, 900), 
                 15, (500, 700),
                 12, (300, 500), 
                 50, (100, 300),
                 (1000, 1500), (1000, 1500),
                 (1, 10), (1, 10), (1, 10), random_state=42
             )

# %%
generate_ampl('data/test2.txt', 'data/test2_ampl.mod')

# %%
generate_file('data/test3.txt',
                 10, (700, 900), 
                 6, (500, 700),
                 8, (300, 500), 
                 100, (100, 300),
                 (1000, 1500), (1000, 1500),
                 (1, 10), (1, 10), (1, 10), random_state=42
             )

# %%
generate_ampl('data/test3.txt', 'data/test3_ampl.mod')

# %%
generate_file('data/test4.txt',
                 20, (700, 900), 
                 15, (500, 700),
                 12, (300, 500), 
                 100, (100, 300),
                 (1000, 1500), (1000, 1500),
                 (1, 10), (1, 10), (1, 10), random_state=42
             )

# %%
generate_ampl('data/test4.txt', 'data/test4_ampl.mod')

# %% [markdown]
# ## Run models

# %%
from utils import load_file
E, D, W, d, g, v, t, a, c = load_file('data/test1.txt')

# %%
from utils import chromosome_fitness
from utils import init_genetic_algorithm
from deap import tools, algorithms

toolbox, stats = init_genetic_algorithm(chromosome_fitness,
                            E, D, W, d, g, v, t, a, c)
pop = toolbox.population(n=100)
hof = tools.HallOfFame(5)

# %%
pop, log = algorithms.eaSimple(pop, toolbox, cxpb=0.5, mutpb=0.2,
                              ngen=30, stats=stats, halloffame=hof,
                              verbose=True)
# Out:
# gen	nevals	Avg    	Std    	Min  	Max
# 0  	100   	44644.3	2920.57	36590	51060
# 1  	55    	42830.1	2670.69	34090	47830
# 2  	65    	42116.4	2881.84	36020	47720
# 3  	58    	41735.5	2785.44	37080	48890
# 4  	52    	40649.3	2449.08	35340	46950
# 5  	63    	40301.3	2753.29	35340	47430
# 6  	52    	39794.9	2655.09	35600	48070
# 7  	73    	39598.7	2720.31	35790	48130
# 8  	62    	38920  	2377.33	36560	48560
# 9  	59    	38813.1	2500.88	36540	46920
# 10 	52    	38407.2	2522.47	35370	47740
# 11 	56    	38067.1	2458.86	35030	46510
# 12 	68    	37719.9	2902.25	34340	47780
# 13 	67    	37007.4	1970.3 	34250	45790
# 14 	54    	36803.5	2346.1 	34550	47230
# 15 	62    	36437.3	2375.59	33920	46850
# 16 	71    	35907  	2101.21	32790	46040
# 17 	60    	35547.8	1995.33	32790	43090
# 18 	47    	34867.7	1775.51	32790	44340
# 19 	61    	34932.4	2621.28	32410	44280
# 20 	56    	34087.3	2312.5 	32410	43460
# 21 	71    	33771.4	2070.14	32410	40790
# 22 	60    	33440  	1870.18	32410	42150
# 23 	62    	33413.1	1970.57	32410	44390
# 24 	60    	34040.1	2930.52	32410	46460
# 25 	72    	34064  	2898.94	32410	45310
# 26 	58    	33904.8	3262.63	32410	48310
# 27 	47    	33445.3	2908.71	32330	47970
# 28 	54    	33111.3	2007.41	32330	41810
# 29 	64    	33285.7	2589.96	32290	44570
# 30 	67    	33270.6	2499.86	32290	45650

# %%
from utils import plot_log
plot_log(log)

# %%
generate_file('data/dev_test.txt',
                 5, (700, 900), 
                 5, (500, 700),
                 5, (300, 500), 
                 5, (100, 300),
                 (1000, 1500), (1000, 1500),
                 (1, 10), (1, 10), (1, 10), random_state=42
             )

# %%
generate_ampl('data/dev_test.txt', 'modelos/dev_test.mod')

# %%
E, D, W, d, g, v, t, a, c = load_file('data/dev_test.txt')

# %%
toolbox, stats = init_genetic_algorithm(chromosome_fitness,
                            E, D, W, d, g, v, t, a, c)
pop = toolbox.population(n=100)
hof = tools.HallOfFame(5)

# %%
pop, log = algorithms.eaSimple(pop, toolbox, cxpb=0.5, mutpb=0.2,
                              ngen=30, stats=stats, halloffame=hof,
                              verbose=True)
# Out:
# gen	nevals	Avg    	Std    	Min  	Max
# 0  	100   	17629.3	1750.27	13570	21490
# 1  	59    	16442.3	1722.72	13390	21730
# 2  	65    	15533.1	1524.45	13150	19210
# 3  	69    	15063.6	1536.12	13150	20210
# 4  	58    	14470.6	1521.03	13150	21450
# 5  	70    	14380.8	1341.05	13150	18870
# 6  	59    	13985.1	1297.72	13150	19620
# 7  	54    	13736.1	1028.09	13150	19220
# 8  	51    	13863.5	1410.54	13150	20760
# 9  	58    	13655.1	1093.05	13150	18000
# 10 	62    	13837.5	1308.7 	13150	18470
# 11 	52    	13705.6	1364   	13150	20160
# 12 	56    	13540.6	952.664	13150	18600
# 13 	62    	13798.7	1343.7 	13150	19440
# 14 	59    	13764.1	1298.64	13150	19210
# 15 	54    	13838.1	1524.87	13150	20180
# 16 	42    	13555  	1261.86	13150	19420
# 17 	56    	13452.6	1022.17	13150	19980
# 18 	64    	13557.5	998.918	13150	17420
# 19 	64    	13641  	1348.95	13150	19370
# 20 	67    	13394.3	733.157	13150	17540
# 21 	68    	13793.9	1524.1 	13150	19920
# 22 	56    	13407.5	977.656	13150	20070
# 23 	65    	13500.1	924.353	13150	17460
# 24 	58    	13615.2	1239.26	13150	18740
# 25 	63    	13725.1	1577.3 	13150	20900
# 26 	74    	13582.4	1112.76	13150	19180
# 27 	61    	13617.2	1283.3 	13150	19260
# 28 	56    	13555.3	1113.34	13150	18590
# 29 	62    	13390.4	757.279	13150	17430
# 30 	54    	13572.5	1194.9 	13150	18550

# %%
plot_log(log)

# %%
from utils import decode_chromosome, plot_graph
q, z, f, p, b, s = decode_chromosome(hof.items[0], E, D, W, d, t, a, c)
plot_graph(b, f, q)

# %%
sum(E), sum(D), sum(W), sum(d)
# Out:
# (4060, 2970, 1760, 890)

# %% [markdown]
# ## Test 1

# %%
E, D, W, d, g, v, t, a, c = load_file('data/test1.txt')

# %%
toolbox, stats = init_genetic_algorithm(chromosome_fitness,
                            E, D, W, d, g, v, t, a, c)
pop = toolbox.population(n=100)
hof = tools.HallOfFame(5)

# %%
pop, log = algorithms.eaSimple(pop, toolbox, cxpb=0.5, mutpb=0.2,
                              ngen=30, stats=stats, halloffame=hof,
                              verbose=True)
# Out:
# gen	nevals	Avg    	Std    	Min  	Max
# 0  	100   	42325.3	2305.43	36980	49070
# 1  	69    	41316.3	2022.49	35100	47480
# 2  	58    	40557  	2015.35	37580	46400
# 3  	56    	39842.4	1769.44	36530	45070
# 4  	60    	39619.4	1939.39	36530	44920
# 5  	64    	39277.6	1891.7 	35780	44920
# 6  	63    	39461.5	2263.22	35260	47340
# 7  	50    	38867.1	1924.32	35260	45000
# 8  	65    	38891.8	2229.59	34930	46670
# 9  	53    	38354.9	2068.08	34930	44730
# 10 	70    	38563.3	2203.67	35260	46090
# 11 	55    	38324.6	2208.9 	35260	44820
# 12 	77    	38363.9	2235.25	35260	44200
# 13 	55    	37988.1	2472.86	34300	44100
# 14 	66    	37229.8	2293.79	34300	44720
# 15 	69    	36836.1	2072.86	34300	44910
# 16 	50    	35861.1	1355.02	34300	41020
# 17 	63    	36264.1	2012.3 	34300	44810
# 18 	58    	35972.5	1655.88	34300	42020
# 19 	52    	35991.6	2084.63	34300	44040
# 20 	59    	35805  	1797.31	34170	40800
# 21 	62    	35684.5	1920.05	34170	43520
# 22 	56    	35313.2	1704.77	34170	42410
# 23 	62    	35016.3	1366.32	33590	40170
# 24 	63    	35148.9	1686.37	33590	41950
# 25 	56    	35100.9	1896.05	33590	46340
# 26 	64    	35174.8	1826.34	33590	41630
# 27 	63    	35434.2	2040.37	33590	43340
# 28 	68    	35234.3	2051.7 	33590	43010
# 29 	52    	35101.7	1938.61	33590	40790
# 30 	59    	34643.4	1590.67	33590	41050

# %%
plot_log(log)

# %%
q, z, f, p, b, s = decode_chromosome(hof.items[0], E, D, W, d, t, a, c)
plot_graph(b, f, q, figsize=(20,30))
